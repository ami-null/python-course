# %% [markdown]
# # Pandas
#
# `pandas` is an open-source module for Python that contains data structures and data manipulation tools designed to make data cleaning and analysis fast and convenient in Python.
#
# It adopts significant parts of NumPy's idiomatic style of array-based computing, especially array-based functions and a preference for data processing without for loops.
#
# While `pandas` adopts many coding idioms from `NumPy`, the biggest difference is that `pandas` is designed for working with tabular or heterogeneous data. `NumPy`, by contrast, is best suited for working with homogeneously typed numerical array data

# %% [markdown]
# ## Installation
#
# Run the following in the terminal:
# `pip install pandas`
#
# If running inside Jupyter/Colab notebook, run:
# `!pip install pandas`

# %% [markdown]
# ## Getting Started
#
# Two central concepts in `pandas` are: `Series` and `DataFrame`.
#
# - A `Series` is like a vector or a column containing some values of the same datatype
# - A `DataFrame` is a table consisting of one or more `Series`. Each series can have its own datatype

# %% [markdown]
# ## `Series`
# - A Series is a one-dimensional array-like object containing a sequence of values (of similar types to NumPy types) of the same type
# - Every `Series` has an associated array of data labels, called its `index`

# %%
import pandas as pd

# %%
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj[0:2]    # we can perform slicing just like in numpy
# Out:
# 0    4
# 1    7
# dtype: int64

# %% [markdown]
# Since we did not specify an index for the data, a default one consisting of the integers 0 through N-1 (where N is the length of the data) is created

# %% [markdown]
# We can also create a Series with an index identifying each data point with a label:

# %%
obj2 = pd.Series([4, 7, -5, 3], index=["d", "b", "a", "c"])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2["b"]
# Out:
# np.int64(7)

# %% [markdown]
# ## `DataFrame`
# A `DataFrame` represents a rectangular table of data and contains an ordered, named collection of columns, each of which can be a different value type (numeric, string, Boolean, etc.).
#
# There are many ways to construct a `DataFrame` from scratch, though one of the most common is from a dictionary (`dict`) of equal-length `list`s or `NumPy` arrays

# %%
data = {"state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
        "year": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# The resulting `DataFrame` has its `index` assigned automatically, as with `Series`, and the columns are placed according to the order of the keys in data (which depends on their insertion order in the dictionary)

# %% [markdown]
# ## Reading and Writing Data using `pandas`
#
# | Function       | Description                                                                                              |
# |----------------|----------------------------------------------------------------------------------------------------------|
# | read_csv       | Load delimited data from a file, URL, or file-like object; use comma as default delimiter                |
# | read_clipboard | Variation of read_csv that reads data from the clipboard; useful for converting tables from web pages    |
# | read_excel     | Read tabular data from an Excel XLS or XLSX file                                                         |
# | read_json      | Read data from a JSON (JavaScript Object Notation) string representation, file, URL, or file-like object |
# | read_sas       | Read a SAS dataset stored in one of the SAS system's custom storage formats                              |
# | read_spss      | Read a data file created by SPSS                                                                         |
# | read_stata     | Read a dataset from Stata file format                                                                    |

# %% [markdown]
# ## Loading the data
#
# We shall now load the IMDb Top 1000 Movies Dataset (https://www.kaggle.com/datasets/moazeldsokyx/imdb-top-10000-movies-dataset). It contains rating, runtime, genre, metascore, plot, directors, stars, votes, gross earnings etc of 9999 movies up to June 2023.

# %%
movies_df = pd.read_csv("https://github.com/ami-null/python-course/raw/refs/heads/main/data/Top_10000_Movies_IMDb.csv")

# %% [markdown]
# After loading the data, we should view the basic informations regarding the columns:

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          9999 non-null   int64
#  1   Movie Name  9999 non-null   object
#  2   Rating      9999 non-null   float64
#  3   Runtime     9999 non-null   object
#  4   Genre       9999 non-null   object
#  5   Metascore   7992 non-null   float64
#  6   Plot        9999 non-null   object
#  7   Directors   9999 non-null   object
#  8   Stars       9999 non-null   object
#  9   Votes       9999 non-null   int64
#  10  Gross       9999 non-null   int64
#  11  Link        9999 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 937.5+ KB

# %%
movies_df.shape
# Out:
# (9999, 12)

# %% [markdown]
# We see that the data has 12 columns, 9999 rows, and only the `Metascore` column has missing values. It also shows the data type of each column. The columns with `Dtype` as `object` can be strings, lists etc.

# %% [markdown]
# We should also print out a few rows of the dataset to keep as a visual reference. We accomplish this with `.head()` method:

# %%
movies_df.head()
# Out:
#    ID                           Movie Name  Rating  Runtime  \
# 0   1             The Shawshank Redemption     9.3  142 min
# 1   2                        The Godfather     9.2  175 min
# 2   3  Ramayana: The Legend of Prince Rama     9.2  135 min
# 3   4                      The Chaos Class     9.2   87 min
# 4   5                                Daman     9.1  121 min
#
#                           Genre  Metascore  \
# 0                         Drama       82.0
# 1                  Crime, Drama      100.0
# 2  Animation, Action, Adventure        NaN
# 3                 Comedy, Drama        NaN
# 4              Adventure, Drama        NaN
#
#                                                 Plot  \
# 0  Over the course of several years, two convicts...
# 1  Don Vito Corleone, head of a mafia family, dec...
# 2  An anime adaptation of the Hindu epic the Rama...
# 3  Lazy, uneducated students share a very close b...
# 4  The film is set in 2015. Sid, is a young docto...
#
#                                            Directors  \
# 0  ['Frank Darabont', 'Tim Robbins', 'Morgan Free...
# 1  ['Francis Ford Coppola', 'Marlon Brando', 'Al ...
# 2  ['Ram Mohan', 'Yûgô Sakô', 'Koichi Saski', 'Ar...
# 3  ['Ertem Egilmez', 'Kemal Sunal', 'Münir Özkul'...
# 4  ['Lenka Debiprasad', 'Vishal Mourya', 'Karan K...
#
#                                                Stars    Votes      Gross  \
# 0  ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...  2752419   28341469
# 1  ['Marlon Brando', 'Al Pacino', 'James Caan', '...  1914751  134966411
# 2  ['Yûgô Sakô', 'Koichi Saski', 'Arun Govil', 'N...    10108      10108
# 3  ['Kemal Sunal', 'Münir Özkul', 'Halit Akçatepe...    41785      41785
# 4  ['Vishal Mourya', 'Karan Kandhapan', 'Babushan...    13303      13303
#
#                                      Link
# 0   https://www.imdb.com/title/tt0111161/
# 1   https://www.imdb.com/title/tt0068646/
# 2   https://www.imdb.com/title/tt0259534/
# 3   https://www.imdb.com/title/tt0252487/
# 4  https://www.imdb.com/title/tt17592606/

# %% [markdown]
# `.head()` outputs the first five rows of a DataFrame by default, but we could also pass a number as well: `movies_df.head(10)` would output the first ten rows, for example.
#
# Further, in the above output, we see that the `Metascore` column has some `NaN` values. `NaN` means "not a number" and indicates missing values in the case of numeric columns. In columns with other data types, `None` or `<NA>` might be used to indicated missing values.

# %%
# we don't want spaces inside column names
movies_df = movies_df.rename(columns = {"Movie Name" : "title"})

# %% [markdown]
# To see the last five rows, we can use `.tail()` method.
#
# `.tail()` also accepts a number, and in this case we printing the bottom three rows:

# %%
movies_df.tail(3)
# Out:
#         ID                  title  Rating Runtime                      Genre  \
# 9996  9997  Paranormal Activity 4     4.6  88 min            Horror, Mystery
# 9997  9998            Dark Crimes     4.6  92 min      Crime, Drama, Mystery
# 9998  9999            The Pyramid     4.6  89 min  Horror, Mystery, Thriller
#
#       Metascore                                               Plot  \
# 9996       40.0  It has been five years since the disappearance...
# 9997       24.0  A murder investigation of a slain businessman ...
# 9998       24.0  An archaeological team attempts to unlock the ...
#
#                                               Directors  \
# 9996  ['Henry Joost', 'Ariel Schulman', 'Stephen Dun...
# 9997  ['Alexandros Avranas', 'Jim Carrey', 'Marton C...
# 9998  ['Grégory Levasseur', 'Ashley Hinshaw', 'James...
#
#                                                   Stars  Votes     Gross  \
# 9996  ['Ariel Schulman', 'Stephen Dunham', 'Katie Fe...  68430  53921300
# 9997  ['Jim Carrey', 'Marton Csokas', 'Charlotte Gai...  19098     19098
# 9998  ['Ashley Hinshaw', 'James Buckley', "Denis O'H...  25483   2756333
#
#                                        Link
# 9996  https://www.imdb.com/title/tt2109184/
# 9997  https://www.imdb.com/title/tt1901024/
# 9998  https://www.imdb.com/title/tt2799166/

# %% [markdown]
# In this `DataFrame` the index is an integer ranging from 0 to 9998 (since the data contains 9999) movies. We can change the index to be either the `ID` column of the dataset or the `Title` column

# %%
mv_idx = movies_df.set_index("ID")
mv_idx.head(3)
# Out:
#                                   title  Rating  Runtime  \
# ID
# 1              The Shawshank Redemption     9.3  142 min
# 2                         The Godfather     9.2  175 min
# 3   Ramayana: The Legend of Prince Rama     9.2  135 min
#
#                            Genre  Metascore  \
# ID
# 1                          Drama       82.0
# 2                   Crime, Drama      100.0
# 3   Animation, Action, Adventure        NaN
#
#                                                  Plot  \
# ID
# 1   Over the course of several years, two convicts...
# 2   Don Vito Corleone, head of a mafia family, dec...
# 3   An anime adaptation of the Hindu epic the Rama...
#
#                                             Directors  \
# ID
# 1   ['Frank Darabont', 'Tim Robbins', 'Morgan Free...
# 2   ['Francis Ford Coppola', 'Marlon Brando', 'Al ...
# 3   ['Ram Mohan', 'Yûgô Sakô', 'Koichi Saski', 'Ar...
#
#                                                 Stars    Votes      Gross  \
# ID
# 1   ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...  2752419   28341469
# 2   ['Marlon Brando', 'Al Pacino', 'James Caan', '...  1914751  134966411
# 3   ['Yûgô Sakô', 'Koichi Saski', 'Arun Govil', 'N...    10108      10108
#
#                                      Link
# ID
# 1   https://www.imdb.com/title/tt0111161/
# 2   https://www.imdb.com/title/tt0068646/
# 3   https://www.imdb.com/title/tt0259534/

# %%
mv_ttl = movies_df.set_index("title")
mv_ttl.head(3)
# Out:
#                                      ID  Rating  Runtime  \
# title
# The Shawshank Redemption              1     9.3  142 min
# The Godfather                         2     9.2  175 min
# Ramayana: The Legend of Prince Rama   3     9.2  135 min
#
#                                                             Genre  Metascore  \
# title
# The Shawshank Redemption                                    Drama       82.0
# The Godfather                                        Crime, Drama      100.0
# Ramayana: The Legend of Prince Rama  Animation, Action, Adventure        NaN
#
#                                                                                   Plot  \
# title
# The Shawshank Redemption             Over the course of several years, two convicts...
# The Godfather                        Don Vito Corleone, head of a mafia family, dec...
# Ramayana: The Legend of Prince Rama  An anime adaptation of the Hindu epic the Rama...
#
#                                                                              Directors  \
# title
# The Shawshank Redemption             ['Frank Darabont', 'Tim Robbins', 'Morgan Free...
# The Godfather                        ['Francis Ford Coppola', 'Marlon Brando', 'Al ...
# Ramayana: The Legend of Prince Rama  ['Ram Mohan', 'Yûgô Sakô', 'Koichi Saski', 'Ar...
#
#                                                                                  Stars  \
# title
# The Shawshank Redemption             ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...
# The Godfather                        ['Marlon Brando', 'Al Pacino', 'James Caan', '...
# Ramayana: The Legend of Prince Rama  ['Yûgô Sakô', 'Koichi Saski', 'Arun Govil', 'N...
#
#                                        Votes      Gross  \
# title
# The Shawshank Redemption             2752419   28341469
# The Godfather                        1914751  134966411
# Ramayana: The Legend of Prince Rama    10108      10108
#
#                                                                       Link
# title
# The Shawshank Redemption             https://www.imdb.com/title/tt0111161/
# The Godfather                        https://www.imdb.com/title/tt0068646/
# Ramayana: The Legend of Prince Rama  https://www.imdb.com/title/tt0259534/

# %% [markdown]
# ## Handling missing values
#
# First, we have check which columns have missing values. The `.isnull()` method returns a `DataFrame` containing the same number of rows and columns as the original `DataFrame` but each cell is either `True` or `False` indicating whether the data has missing value in the corresponding cell.

# %%
movies_df.isnull()
# Out:
#          ID  title  Rating  Runtime  Genre  Metascore   Plot  Directors  \
# 0     False  False   False    False  False      False  False      False
# 1     False  False   False    False  False      False  False      False
# 2     False  False   False    False  False       True  False      False
# 3     False  False   False    False  False       True  False      False
# 4     False  False   False    False  False       True  False      False
# ...     ...    ...     ...      ...    ...        ...    ...        ...
# 9994  False  False   False    False  False      False  False      False
# 9995  False  False   False    False  False      False  False      False
# 9996  False  False   False    False  False      False  False      False
# 9997  False  False   False    False  False      False  False      False
# 9998  False  False   False    False  False      False  False      False
#
#       Stars  Votes  Gross   Link
# 0     False  False  False  False
# 1     False  False  False  False
# 2     False  False  False  False
# 3     False  False  False  False
# 4     False  False  False  False
# ...     ...    ...    ...    ...
# 9994  False  False  False  False
# 9995  False  False  False  False
# 9996  False  False  False  False
# 9997  False  False  False  False
# 9998  False  False  False  False
#
# [9999 rows x 12 columns]

# %%
# we can sum the output of .isnull() to get count of missing values
movies_df.isnull().sum()
# Out:
# ID              0
# title           0
# Rating          0
# Runtime         0
# Genre           0
# Metascore    2007
# Plot            0
# Directors       0
# Stars           0
# Votes           0
# Gross           0
# Link            0
# dtype: int64

# %% [markdown]
# The `Metascore` column has some missing values.

# %% [markdown]
# ### Complete case analysis

# %% [markdown]
# We can drop the missing rows containing values and perform further analysis with only the complete observations (this is known as complete case analysis).

# %%
movies_cc = movies_df.dropna()
movies_cc.isna().sum()    # the .isna() method can also be used
# Out:
# ID           0
# title        0
# Rating       0
# Runtime      0
# Genre        0
# Metascore    0
# Plot         0
# Directors    0
# Stars        0
# Votes        0
# Gross        0
# Link         0
# dtype: int64

# %% [markdown]
# ### Imputation
# Imputation means filling out the missing values in a dataset with plausible values based on some criteria/logic/algorithm. There are many basic and advanced forms of imputation, however, they are out of the scope of this course. Therefore, we shall limit discussion on imputation at a minimum.
#
# Missing values can be filled with the `.fillna()` method.

# %%
# replacing the missing values with the overall average value
movies_df['Metascore'] = movies_df['Metascore'].fillna(movies_df['Metascore'].mean())

# %%
movies_df['Metascore'].isnull().sum()    # missing count 0 now
# Out:
# np.int64(0)

# %% [markdown]
# ## Indexing and Slicing a `DataFrame`

# %% [markdown]
# ### Selecting a single column

# %%
genre_col = movies_df['Genre']

# %%
genre_col
# Out:
# 0                              Drama
# 1                       Crime, Drama
# 2       Animation, Action, Adventure
# 3                      Comedy, Drama
# 4                   Adventure, Drama
#                     ...
# 9994    Animation, Adventure, Comedy
# 9995         Comedy, Fantasy, Horror
# 9996                 Horror, Mystery
# 9997           Crime, Drama, Mystery
# 9998       Horror, Mystery, Thriller
# Name: Genre, Length: 9999, dtype: object

# %%
print(type(genre_col))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(movies_df.Genre))    # same as above
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# We can see above that selecting a single column with the `df['col_name']` syntax or the `df.col_name` syntax returns a `Series` object.

# %% [markdown]
# ### Selecting multiple columns
#
# We can also select one or more columns with `df[['col1', 'col2',...]` syntax. In this case the return value would of type `DataFrame` (even if we select only one column)

# %%
movies_df[['title', 'Runtime']].head(4)
# Out:
#                                  title  Runtime
# 0             The Shawshank Redemption  142 min
# 1                        The Godfather  175 min
# 2  Ramayana: The Legend of Prince Rama  135 min
# 3                      The Chaos Class   87 min

# %%
print(type(movies_df[['title', 'Runtime']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(movies_df[['title']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Selecting Columns Based on Data Types
#
# Below we select the numeric columns:

# %%
movies_num = movies_df.select_dtypes("number")
movies_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         9999 non-null   int64
#  1   Rating     9999 non-null   float64
#  2   Metascore  9999 non-null   float64
#  3   Votes      9999 non-null   int64
#  4   Gross      9999 non-null   int64
# dtypes: float64(2), int64(3)
# memory usage: 390.7 KB

# %% [markdown]
# ### Selecting Rows
#
# For slicing DataFrames by rows, we have two options
# - `.loc` - locates by name or label
# - `.iloc` - locates by numerical index
#
# Earlier we defined `mv_ttl` which is the same as `movies_df` but with the `index` set to the `title` column.

# %% [markdown]
# #### Using `.iloc`

# %%
mv_ttl.iloc[0:4]
# Out:
#                                      ID  Rating  Runtime  \
# title
# The Shawshank Redemption              1     9.3  142 min
# The Godfather                         2     9.2  175 min
# Ramayana: The Legend of Prince Rama   3     9.2  135 min
# The Chaos Class                       4     9.2   87 min
#
#                                                             Genre  Metascore  \
# title
# The Shawshank Redemption                                    Drama       82.0
# The Godfather                                        Crime, Drama      100.0
# Ramayana: The Legend of Prince Rama  Animation, Action, Adventure        NaN
# The Chaos Class                                     Comedy, Drama        NaN
#
#                                                                                   Plot  \
# title
# The Shawshank Redemption             Over the course of several years, two convicts...
# The Godfather                        Don Vito Corleone, head of a mafia family, dec...
# Ramayana: The Legend of Prince Rama  An anime adaptation of the Hindu epic the Rama...
# The Chaos Class                      Lazy, uneducated students share a very close b...
#
#                                                                              Directors  \
# title
# The Shawshank Redemption             ['Frank Darabont', 'Tim Robbins', 'Morgan Free...
# The Godfather                        ['Francis Ford Coppola', 'Marlon Brando', 'Al ...
# Ramayana: The Legend of Prince Rama  ['Ram Mohan', 'Yûgô Sakô', 'Koichi Saski', 'Ar...
# The Chaos Class                      ['Ertem Egilmez', 'Kemal Sunal', 'Münir Özkul'...
#
#                                                                                  Stars  \
# title
# The Shawshank Redemption             ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...
# The Godfather                        ['Marlon Brando', 'Al Pacino', 'James Caan', '...
# Ramayana: The Legend of Prince Rama  ['Yûgô Sakô', 'Koichi Saski', 'Arun Govil', 'N...
# The Chaos Class                      ['Kemal Sunal', 'Münir Özkul', 'Halit Akçatepe...
#
#                                        Votes      Gross  \
# title
# The Shawshank Redemption             2752419   28341469
# The Godfather                        1914751  134966411
# Ramayana: The Legend of Prince Rama    10108      10108
# The Chaos Class                        41785      41785
#
#                                                                       Link
# title
# The Shawshank Redemption             https://www.imdb.com/title/tt0111161/
# The Godfather                        https://www.imdb.com/title/tt0068646/
# Ramayana: The Legend of Prince Rama  https://www.imdb.com/title/tt0259534/
# The Chaos Class                      https://www.imdb.com/title/tt0252487/

# %% [markdown]
# In `.iloc` we can also mention specific columns to select. Inside the brackets, the indices before the comma specifies rows and indices after the comma specifies columns:

# %%
mv_ttl.iloc[0:4, 1:3]    # First four rows, 2nd and 3rd columns
# Out:
#                                      Rating  Runtime
# title
# The Shawshank Redemption                9.3  142 min
# The Godfather                           9.2  175 min
# Ramayana: The Legend of Prince Rama     9.2  135 min
# The Chaos Class                         9.2   87 min

# %% [markdown]
# #### Using `.loc`

# %%
mv_ttl.loc["The Shawshank Redemption":"The Chaos Class", "Rating":"Runtime"]
# Out:
#                                      Rating  Runtime
# title
# The Shawshank Redemption                9.3  142 min
# The Godfather                           9.2  175 min
# Ramayana: The Legend of Prince Rama     9.2  135 min
# The Chaos Class                         9.2   87 min

# %% [markdown]
# #### Inconsistency between `.loc` and `.iloc`
#
# When slicing with `.iloc`, the last index in the slice is *NOT included* in the output. However, when indexing with `.loc`, the last index is *included* in the output. See the above outputs for an example.

# %% [markdown]
# ## Filtering Values (selecting rows based on conditions)

# %% [markdown]
# Selecting movies with a high rating:

# %%
movies_df[movies_df['Rating'] > 8]
# Out:
#       ID                                title  Rating  Runtime  \
# 0      1             The Shawshank Redemption     9.3  142 min
# 1      2                        The Godfather     9.2  175 min
# 2      3  Ramayana: The Legend of Prince Rama     9.2  135 min
# 3      4                      The Chaos Class     9.2   87 min
# 4      5                                Daman     9.1  121 min
# ..   ...                                  ...     ...      ...
# 491  492                                Anand     8.1  122 min
# 492  493                                Iqbal     8.1  132 min
# 493  494           The Legend of Bhagat Singh     8.1  155 min
# 494  495                               Ghilli     8.1  160 min
# 495  496                              Kaththi     8.1  166 min
#
#                             Genre   Metascore  \
# 0                           Drama   82.000000
# 1                    Crime, Drama  100.000000
# 2    Animation, Action, Adventure   58.749625
# 3                   Comedy, Drama   58.749625
# 4                Adventure, Drama   58.749625
# ..                            ...         ...
# 491                Drama, Musical   58.749625
# 492                  Drama, Sport   58.749625
# 493      Action, Biography, Drama   58.749625
# 494        Action, Drama, Romance   58.749625
# 495                 Action, Drama   58.749625
#
#                                                   Plot  \
# 0    Over the course of several years, two convicts...
# 1    Don Vito Corleone, head of a mafia family, dec...
# 2    An anime adaptation of the Hindu epic the Rama...
# 3    Lazy, uneducated students share a very close b...
# 4    The film is set in 2015. Sid, is a young docto...
# ..                                                 ...
# 491  The story of a terminally ill man who wishes t...
# 492  Iqbal, the deaf and mute son of a farmer, has ...
# 493  The story of a young revolutionary who raised ...
# 494  Velu, an aspiring kabaddi player, goes to Madu...
# 495  A case of mistaken identity embroils an escape...
#
#                                              Directors  \
# 0    ['Frank Darabont', 'Tim Robbins', 'Morgan Free...
# 1    ['Francis Ford Coppola', 'Marlon Brando', 'Al ...
# 2    ['Ram Mohan', 'Yûgô Sakô', 'Koichi Saski', 'Ar...
# 3    ['Ertem Egilmez', 'Kemal Sunal', 'Münir Özkul'...
# 4    ['Lenka Debiprasad', 'Vishal Mourya', 'Karan K...
# ..                                                 ...
# 491  ['Hrishikesh Mukherjee', 'Rajesh Khanna', 'Ami...
# 492  ['Nagesh Kukunoor', 'Shreyas Talpade', 'Naseer...
# 493  ['Rajkumar Santoshi', 'Ajay Devgn', 'Sushant S...
# 494  ['Dharani', 'Joseph Vijay', 'Trisha Krishnan',...
# 495  ['A.R. Murugadoss', 'Joseph Vijay', 'Samantha ...
#
#                                                  Stars    Votes      Gross  \
# 0    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...  2752419   28341469
# 1    ['Marlon Brando', 'Al Pacino', 'James Caan', '...  1914751  134966411
# 2    ['Yûgô Sakô', 'Koichi Saski', 'Arun Govil', 'N...    10108      10108
# 3    ['Kemal Sunal', 'Münir Özkul', 'Halit Akçatepe...    41785      41785
# 4    ['Vishal Mourya', 'Karan Kandhapan', 'Babushan...    13303      13303
# ..                                                 ...      ...        ...
# 491  ['Rajesh Khanna', 'Amitabh Bachchan', 'Sumita ...    34462      34462
# 492  ['Shreyas Talpade', 'Naseeruddin Shah', 'Shwet...    17329      17329
# 493  ['Ajay Devgn', 'Sushant Singh', 'D. Santosh', ...    16881      16881
# 494  ['Joseph Vijay', 'Trisha Krishnan', 'Prakash R...    15531      15531
# 495  ['Joseph Vijay', 'Samantha Ruth Prabhu', 'Neil...    28363      28363
#
#                                        Link
# 0     https://www.imdb.com/title/tt0111161/
# 1     https://www.imdb.com/title/tt0068646/
# 2     https://www.imdb.com/title/tt0259534/
# 3     https://www.imdb.com/title/tt0252487/
# 4    https://www.imdb.com/title/tt17592606/
# ..                                      ...
# 491   https://www.imdb.com/title/tt0066763/
# 492   https://www.imdb.com/title/tt0453729/
# 493   https://www.imdb.com/title/tt0319736/
# 494   https://www.imdb.com/title/tt0422320/
# 495   https://www.imdb.com/title/tt3801314/
#
# [496 rows x 12 columns]

# %% [markdown]
# Sometimes a high rating alone may not be indicative of a good movie, so we can filter with a high number of votes too:

# %%
movies_df[(movies_df['Rating'] > 8) & (movies_df['Votes'] > 100000)]
# Out:
#       ID                                title  Rating  Runtime  \
# 0      1             The Shawshank Redemption     9.3  142 min
# 1      2                        The Godfather     9.2  175 min
# 5      6  Spider-Man: Across the Spider-Verse     9.0  140 min
# 6      7                      The Dark Knight     9.0  152 min
# 7      8                     Schindler's List     9.0  195 min
# ..   ...                                  ...     ...      ...
# 408  409                    Wild Strawberries     8.1   91 min
# 417  418    Lagaan: Once Upon a Time in India     8.1  224 min
# 419  420         Mr. Smith Goes to Washington     8.1  129 min
# 432  433                        The Gold Rush     8.1   95 min
# 449  450                      Rang De Basanti     8.1  167 min
#
#                             Genre   Metascore  \
# 0                           Drama   82.000000
# 1                    Crime, Drama  100.000000
# 5    Animation, Action, Adventure   86.000000
# 6            Action, Crime, Drama   84.000000
# 7       Biography, Drama, History   95.000000
# ..                            ...         ...
# 408                Drama, Romance   88.000000
# 417         Drama, Musical, Sport   84.000000
# 419                 Comedy, Drama   73.000000
# 432      Adventure, Comedy, Drama   58.749625
# 449          Comedy, Crime, Drama   58.749625
#
#                                                   Plot  \
# 0    Over the course of several years, two convicts...
# 1    Don Vito Corleone, head of a mafia family, dec...
# 5    Miles Morales catapults across the Multiverse,...
# 6    When the menace known as the Joker wreaks havo...
# 7    In German-occupied Poland during World War II,...
# ..                                                 ...
# 408  After living a life marked by coldness, an agi...
# 417  The people of a small village in Victorian Ind...
# 419  A naive youth leader is appointed to fill a va...
# 432  A prospector goes to the Klondike during the 1...
# 449  The story of six young Indians who assist an E...
#
#                                              Directors  \
# 0    ['Frank Darabont', 'Tim Robbins', 'Morgan Free...
# 1    ['Francis Ford Coppola', 'Marlon Brando', 'Al ...
# 5    ['Joaquim Dos Santos', 'Kemp Powers', 'Justin ...
# 6    ['Christopher Nolan', 'Christian Bale', 'Heath...
# 7    ['Steven Spielberg', 'Liam Neeson', 'Ralph Fie...
# ..                                                 ...
# 408  ['Ingmar Bergman', 'Victor Sjöström', 'Bibi An...
# 417  ['Ashutosh Gowariker', 'Aamir Khan', 'Raghubir...
# 419  ['Frank Capra', 'James Stewart', 'Jean Arthur'...
# 432  ['Charles Chaplin', 'Charles Chaplin', 'Mack S...
# 449  ['Rakeysh Omprakash Mehra', 'Aamir Khan', 'Soh...
#
#                                                  Stars    Votes      Gross  \
# 0    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...  2752419   28341469
# 1    ['Marlon Brando', 'Al Pacino', 'James Caan', '...  1914751  134966411
# 5    ['Kemp Powers', 'Justin K. Thompson', 'Shameik...   122030     122030
# 6    ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...  2725188  534858444
# 7    ['Liam Neeson', 'Ralph Fiennes', 'Ben Kingsley...  1387831   96898818
# ..                                                 ...      ...        ...
# 408  ['Victor Sjöström', 'Bibi Andersson', 'Ingrid ...   110195     110195
# 417  ['Aamir Khan', 'Raghubir Yadav', 'Gracy Singh'...   117077      70147
# 419  ['James Stewart', 'Jean Arthur', 'Claude Rains...   117774    9600000
# 432  ['Charles Chaplin', 'Mack Swain', 'Tom Murray'...   114081    5450000
# 449  ['Aamir Khan', 'Soha Ali Khan', 'Siddharth', '...   120551    2197331
#
#                                       Link
# 0    https://www.imdb.com/title/tt0111161/
# 1    https://www.imdb.com/title/tt0068646/
# 5    https://www.imdb.com/title/tt9362722/
# 6    https://www.imdb.com/title/tt0468569/
# 7    https://www.imdb.com/title/tt0108052/
# ..                                     ...
# 408  https://www.imdb.com/title/tt0050986/
# 417  https://www.imdb.com/title/tt0169102/
# 419  https://www.imdb.com/title/tt0031679/
# 432  https://www.imdb.com/title/tt0015864/
# 449  https://www.imdb.com/title/tt0405508/
#
# [241 rows x 12 columns]

# %% [markdown]
# Filtering movies which have only "Action" in their genre:

# %%
movies_df[movies_df["Genre"] == "Action"]
# Out:
#         ID                        title  Rating  Runtime   Genre  Metascore  \
# 85      86                      Banshee     8.5   50 min  Action  58.749625
# 1684  1685                         Ayan     7.6  162 min  Action  58.749625
# 7284  7285                    Ong Bak 2     6.2   98 min  Action  47.000000
# 7707  7708                   Velayudham     6.1  186 min  Action  58.749625
# 9238  9239  The Man with the Iron Fists     5.4   95 min  Action  51.000000
# 9825  9826                    Ong Bak 3     4.9   99 min  Action  38.000000
#
#                                                    Plot  \
# 85    A thief gets out of prison after many years an...
# 1684  A young man's smuggling lifestyle takes a seri...
# 7284  A young Thai boxer learns the skills and inner...
# 7707  After a villager unwittingly prevents a number...
# 9238  On the hunt for a fabled treasure of gold, a b...
# 9825  Continuing from Ong Bak 2's 1440s, Prince Tien...
#
#                                               Directors  \
# 85    ['Gemma Mc Carthy', 'Antony Starr', "Jonathan ...
# 1684  ['K.V. Anand', 'Suriya', 'Tamannaah Bhatia', '...
# 7284  ['Tony Jaa', 'Panna Rittikrai', 'Tony Jaa', 'S...
# 7707  ['Mohan Raja', 'Joseph Vijay', "Genelia D'Souz...
# 9238  ['RZA', 'Russell Crowe', 'Cung Le', 'Lucy Liu'...
# 9825  ['Tony Jaa', 'Panna Rittikrai', 'Tony Jaa', 'D...
#
#                                                   Stars  Votes     Gross  \
# 85    ['Antony Starr', "Jonathan O' Dwyer", 'Sean Fl...  11095     11095
# 1684  ['Suriya', 'Tamannaah Bhatia', 'Prabhu', 'Jagan']  11086     11086
# 7284  ['Panna Rittikrai', 'Tony Jaa', 'Sarunyu Wongk...  31338    102055
# 7707  ['Joseph Vijay', "Genelia D'Souza", 'Hansika M...  12375     12375
# 9238    ['Russell Crowe', 'Cung Le', 'Lucy Liu', 'RZA']  63551  15634090
# 9825  ['Panna Rittikrai', 'Tony Jaa', 'Dan Chupong',...  14331     14498
#
#                                        Link
# 85    https://www.imdb.com/title/tt3396910/
# 1684  https://www.imdb.com/title/tt1355546/
# 7284  https://www.imdb.com/title/tt0785035/
# 7707  https://www.imdb.com/title/tt1965272/
# 9238  https://www.imdb.com/title/tt1258972/
# 9825  https://www.imdb.com/title/tt1653690/

# %% [markdown]
# Filtering movies which have "Action" or "Comedy" in their genre:

# %%
movies_df[(movies_df["Genre"] == "Action") | (movies_df["Genre"] == "Comedy")]
# Out:
#         ID                               title  Rating  Runtime   Genre  \
# 14      15                          Tosun Pasa     8.9   90 min  Comedy
# 15      16    The Chaos Class Failed the Class     8.9   91 min  Comedy
# 85      86                             Banshee     8.5   50 min  Action
# 140    141  When I Grow Up, I'll Be a Kangaroo     8.4   92 min  Comedy
# 520    521                  Young Frankenstein     8.0  106 min  Comedy
# ...    ...                                 ...     ...      ...     ...
# 9916  9917                        Recep Ivedik     4.8   90 min  Comedy
# 9921  9922                          The Bubble     4.7  126 min  Comedy
# 9954  9955      Deuce Bigalow: European Gigolo     4.7   83 min  Comedy
# 9961  9962                         Like a Boss     4.7   83 min  Comedy
# 9989  9990                 Freddy Got Fingered     4.6   87 min  Comedy
#
#       Metascore                                               Plot  \
# 14    58.749625  Two traditionally rival Turkish families, "Sef...
# 15    58.749625  A young and beautiful female teacher starts wo...
# 85    58.749625  A thief gets out of prison after many years an...
# 140   58.749625  During one peculiar night, the lives of severa...
# 520   83.000000  An American grandson of the infamous scientist...
# ...         ...                                                ...
# 9916  58.749625  A man trying to impress his childhood lover, a...
# 9921  34.000000  A group of actors and actresses stuck inside a...
# 9954  23.000000  Deuce is tricked again into man-whoring by T.J...
# 9961  33.000000  Two friends with very different ideals start a...
# 9989  13.000000  An unemployed cartoonist moves back in with hi...
#
#                                               Directors  \
# 14    ['Kartal Tibet', 'Kemal Sunal', 'Müjde Ar', 'A...
# 15    ['Ertem Egilmez', 'Kemal Sunal', 'Münir Özkul'...
# 85    ['Gemma Mc Carthy', 'Antony Starr', "Jonathan ...
# 140   ['Radivoje Andric', 'Sergej Trifunovic', 'Mari...
# 520   ['Mel Brooks', 'Gene Wilder', 'Madeline Kahn',...
# ...                                                 ...
# 9916  ['Togan Gökbakar', 'Sahan Gökbakar', 'Fatma To...
# 9921  ['Judd Apatow', 'Harry Trevaldwyn', 'Samson Ka...
# 9954  ['Mike Bigelow', 'Rob Schneider', 'Eddie Griff...
# 9961  ['Miguel Arteta', 'Tiffany Haddish', 'Rose Byr...
# 9989  ['Tom Green', 'Tom Green', 'Rip Torn', 'Marisa...
#
#                                                   Stars   Votes     Gross  \
# 14    ['Kemal Sunal', 'Müjde Ar', 'Adile Nasit', 'Se...   23933     23933
# 15    ['Kemal Sunal', 'Münir Özkul', 'Semra Özdamar'...   23976     23976
# 85    ['Antony Starr', "Jonathan O' Dwyer", 'Sean Fl...   11095     11095
# 140   ['Sergej Trifunovic', 'Marija Karan', 'Nebojsa...   11116     11116
# 520   ['Gene Wilder', 'Madeline Kahn', 'Marty Feldma...  163092  86300000
# ...                                                 ...     ...       ...
# 9916  ['Sahan Gökbakar', 'Fatma Toptas', 'Tulug Çizg...   27759     27759
# 9921  ['Harry Trevaldwyn', 'Samson Kayo', 'Peter Ser...   26922     26922
# 9954  ['Rob Schneider', 'Eddie Griffin', 'Jeroen Kra...   52178  22264487
# 9961  ['Tiffany Haddish', 'Rose Byrne', 'Salma Hayek...   14781     14781
# 9989  ['Tom Green', 'Rip Torn', 'Marisa Coughlan', '...   49868  14249005
#
#                                         Link
# 14     https://www.imdb.com/title/tt0253828/
# 15     https://www.imdb.com/title/tt0252488/
# 85     https://www.imdb.com/title/tt3396910/
# 140    https://www.imdb.com/title/tt0383846/
# 520    https://www.imdb.com/title/tt0072431/
# ...                                      ...
# 9916   https://www.imdb.com/title/tt1193516/
# 9921  https://www.imdb.com/title/tt13610562/
# 9954   https://www.imdb.com/title/tt0367652/
# 9961   https://www.imdb.com/title/tt7545266/
# 9989   https://www.imdb.com/title/tt0240515/
#
# [265 rows x 12 columns]

# %% [markdown]
# The above query can be concisely written using the `.isin()` method:

# %%
movies_df[movies_df["Genre"].isin(["Action", "Comedy"])]
# Out:
#         ID                               title  Rating  Runtime   Genre  \
# 14      15                          Tosun Pasa     8.9   90 min  Comedy
# 15      16    The Chaos Class Failed the Class     8.9   91 min  Comedy
# 85      86                             Banshee     8.5   50 min  Action
# 140    141  When I Grow Up, I'll Be a Kangaroo     8.4   92 min  Comedy
# 520    521                  Young Frankenstein     8.0  106 min  Comedy
# ...    ...                                 ...     ...      ...     ...
# 9916  9917                        Recep Ivedik     4.8   90 min  Comedy
# 9921  9922                          The Bubble     4.7  126 min  Comedy
# 9954  9955      Deuce Bigalow: European Gigolo     4.7   83 min  Comedy
# 9961  9962                         Like a Boss     4.7   83 min  Comedy
# 9989  9990                 Freddy Got Fingered     4.6   87 min  Comedy
#
#       Metascore                                               Plot  \
# 14    58.749625  Two traditionally rival Turkish families, "Sef...
# 15    58.749625  A young and beautiful female teacher starts wo...
# 85    58.749625  A thief gets out of prison after many years an...
# 140   58.749625  During one peculiar night, the lives of severa...
# 520   83.000000  An American grandson of the infamous scientist...
# ...         ...                                                ...
# 9916  58.749625  A man trying to impress his childhood lover, a...
# 9921  34.000000  A group of actors and actresses stuck inside a...
# 9954  23.000000  Deuce is tricked again into man-whoring by T.J...
# 9961  33.000000  Two friends with very different ideals start a...
# 9989  13.000000  An unemployed cartoonist moves back in with hi...
#
#                                               Directors  \
# 14    ['Kartal Tibet', 'Kemal Sunal', 'Müjde Ar', 'A...
# 15    ['Ertem Egilmez', 'Kemal Sunal', 'Münir Özkul'...
# 85    ['Gemma Mc Carthy', 'Antony Starr', "Jonathan ...
# 140   ['Radivoje Andric', 'Sergej Trifunovic', 'Mari...
# 520   ['Mel Brooks', 'Gene Wilder', 'Madeline Kahn',...
# ...                                                 ...
# 9916  ['Togan Gökbakar', 'Sahan Gökbakar', 'Fatma To...
# 9921  ['Judd Apatow', 'Harry Trevaldwyn', 'Samson Ka...
# 9954  ['Mike Bigelow', 'Rob Schneider', 'Eddie Griff...
# 9961  ['Miguel Arteta', 'Tiffany Haddish', 'Rose Byr...
# 9989  ['Tom Green', 'Tom Green', 'Rip Torn', 'Marisa...
#
#                                                   Stars   Votes     Gross  \
# 14    ['Kemal Sunal', 'Müjde Ar', 'Adile Nasit', 'Se...   23933     23933
# 15    ['Kemal Sunal', 'Münir Özkul', 'Semra Özdamar'...   23976     23976
# 85    ['Antony Starr', "Jonathan O' Dwyer", 'Sean Fl...   11095     11095
# 140   ['Sergej Trifunovic', 'Marija Karan', 'Nebojsa...   11116     11116
# 520   ['Gene Wilder', 'Madeline Kahn', 'Marty Feldma...  163092  86300000
# ...                                                 ...     ...       ...
# 9916  ['Sahan Gökbakar', 'Fatma Toptas', 'Tulug Çizg...   27759     27759
# 9921  ['Harry Trevaldwyn', 'Samson Kayo', 'Peter Ser...   26922     26922
# 9954  ['Rob Schneider', 'Eddie Griffin', 'Jeroen Kra...   52178  22264487
# 9961  ['Tiffany Haddish', 'Rose Byrne', 'Salma Hayek...   14781     14781
# 9989  ['Tom Green', 'Rip Torn', 'Marisa Coughlan', '...   49868  14249005
#
#                                         Link
# 14     https://www.imdb.com/title/tt0253828/
# 15     https://www.imdb.com/title/tt0252488/
# 85     https://www.imdb.com/title/tt3396910/
# 140    https://www.imdb.com/title/tt0383846/
# 520    https://www.imdb.com/title/tt0072431/
# ...                                      ...
# 9916   https://www.imdb.com/title/tt1193516/
# 9921  https://www.imdb.com/title/tt13610562/
# 9954   https://www.imdb.com/title/tt0367652/
# 9961   https://www.imdb.com/title/tt7545266/
# 9989   https://www.imdb.com/title/tt0240515/
#
# [265 rows x 12 columns]

# %% [markdown]
# Selecting movies with gross revenue above the overall 75% percentile of all movies in the datset:

# %%
movies_df[movies_df['Gross'] > movies_df['Gross'].quantile(0.75)]
# Out:
#         ID                                          title  Rating  Runtime  \
# 1        2                                  The Godfather     9.2  175 min
# 6        7                                The Dark Knight     9.0  152 min
# 7        8                               Schindler's List     9.0  195 min
# 9       10                          The Godfather Part II     9.0  202 min
# 10      11  The Lord of the Rings: The Return of the King     9.0  201 min
# ...    ...                                            ...     ...      ...
# 9988  9989                   Aliens vs. Predator: Requiem     4.6   94 min
# 9990  9991                      Hannah Montana: The Movie     4.6  102 min
# 9991  9992                                 God's Not Dead     4.6  113 min
# 9994  9995                                      Yogi Bear     4.6   80 min
# 9996  9997                          Paranormal Activity 4     4.6   88 min
#
#                              Genre  Metascore  \
# 1                     Crime, Drama      100.0
# 6             Action, Crime, Drama       84.0
# 7        Biography, Drama, History       95.0
# 9                     Crime, Drama       90.0
# 10        Action, Adventure, Drama       94.0
# ...                            ...        ...
# 9988     Action, Adventure, Horror       29.0
# 9990         Comedy, Drama, Family       47.0
# 9991      Adventure, Comedy, Drama       16.0
# 9994  Animation, Adventure, Comedy       35.0
# 9996               Horror, Mystery       40.0
#
#                                                    Plot  \
# 1     Don Vito Corleone, head of a mafia family, dec...
# 6     When the menace known as the Joker wreaks havo...
# 7     In German-occupied Poland during World War II,...
# 9     The early life and career of Vito Corleone in ...
# 10    Gandalf and Aragorn lead the World of Men agai...
# ...                                                 ...
# 9988  Warring Alien and Predator races descend on a ...
# 9990  As Hannah Montana's popularity begins to take ...
# 9991  College philosophy professor Mr. Radisson's cu...
# 9994  A documentary filmmaker travels to Jellystone ...
# 9996  It has been five years since the disappearance...
#
#                                               Directors  \
# 1     ['Francis Ford Coppola', 'Marlon Brando', 'Al ...
# 6     ['Christopher Nolan', 'Christian Bale', 'Heath...
# 7     ['Steven Spielberg', 'Liam Neeson', 'Ralph Fie...
# 9     ['Francis Ford Coppola', 'Al Pacino', 'Robert ...
# 10    ['Peter Jackson', 'Elijah Wood', 'Viggo Morten...
# ...                                                 ...
# 9988  ['Colin Strause', 'Greg Strause', 'Reiko Ayles...
# 9990  ['Peter Chelsom', 'Miley Cyrus', 'Emily Osment...
# 9991  ['Harold Cronk', 'Shane Harper', 'Kevin Sorbo'...
# 9994  ['Eric Brevig', 'Dan Aykroyd', 'Justin Timberl...
# 9996  ['Henry Joost', 'Ariel Schulman', 'Stephen Dun...
#
#                                                   Stars    Votes      Gross  \
# 1     ['Marlon Brando', 'Al Pacino', 'James Caan', '...  1914751  134966411
# 6     ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...  2725188  534858444
# 7     ['Liam Neeson', 'Ralph Fiennes', 'Ben Kingsley...  1387831   96898818
# 9     ['Al Pacino', 'Robert De Niro', 'Robert Duvall...  1303858   57300000
# 10    ['Elijah Wood', 'Viggo Mortensen', 'Ian McKell...  1890885  377845905
# ...                                                 ...      ...        ...
# 9988  ['Greg Strause', 'Reiko Aylesworth', 'Steven P...   129456   41797066
# 9990  ['Miley Cyrus', 'Emily Osment', 'Billy Ray Cyr...    44174   79566871
# 9991  ['Shane Harper', 'Kevin Sorbo', 'David A.R. Wh...    43934   60755732
# 9994  ['Dan Aykroyd', 'Justin Timberlake', 'Anna Far...    22762  100246011
# 9996  ['Ariel Schulman', 'Stephen Dunham', 'Katie Fe...    68430   53921300
#
#                                        Link
# 1     https://www.imdb.com/title/tt0068646/
# 6     https://www.imdb.com/title/tt0468569/
# 7     https://www.imdb.com/title/tt0108052/
# 9     https://www.imdb.com/title/tt0071562/
# 10    https://www.imdb.com/title/tt0167260/
# ...                                     ...
# 9988  https://www.imdb.com/title/tt0758730/
# 9990  https://www.imdb.com/title/tt1114677/
# 9991  https://www.imdb.com/title/tt2528814/
# 9994  https://www.imdb.com/title/tt1302067/
# 9996  https://www.imdb.com/title/tt2109184/
#
# [2500 rows x 12 columns]

# %%
# filtering movies with rating between 8 and 9:
movies_df[(movies_df["Rating"] >= 8) & (movies_df["Rating"] <= 9)]
# Out:
#       ID                                title  Rating  Runtime  \
# 5      6  Spider-Man: Across the Spider-Verse     9.0  140 min
# 6      7                      The Dark Knight     9.0  152 min
# 7      8                     Schindler's List     9.0  195 min
# 8      9                         12 Angry Men     9.0   96 min
# 9     10                The Godfather Part II     9.0  202 min
# ..   ...                                  ...     ...      ...
# 670  671              My Grandfather's People     8.0  126 min
# 671  672             Manjhi: The Mountain Man     8.0  120 min
# 672  673                               Pokiri     8.0  164 min
# 673  674               Cars of the Revolution     8.0  115 min
# 674  675                      Abbas in Flower     8.0   87 min
#
#                             Genre  Metascore  \
# 5    Animation, Action, Adventure  86.000000
# 6            Action, Crime, Drama  84.000000
# 7       Biography, Drama, History  95.000000
# 8                    Crime, Drama  97.000000
# 9                    Crime, Drama  90.000000
# ..                            ...        ...
# 670         Comedy, Drama, Family  58.749625
# 671              Biography, Drama  58.749625
# 672       Action, Crime, Thriller  58.749625
# 673                         Drama  58.749625
# 674        Comedy, Drama, Romance  58.749625
#
#                                                   Plot  \
# 5    Miles Morales catapults across the Multiverse,...
# 6    When the menace known as the Joker wreaks havo...
# 7    In German-occupied Poland during World War II,...
# 8    The jury in a New York City murder trial is fr...
# 9    The early life and career of Vito Corleone in ...
# ..                                                 ...
# 670  Grandpapa and his family were torn from their ...
# 671  Using only a hammer and a chisel, a man spends...
# 672  A money-minded criminal has to deal with two r...
# 673  In the years of military coup, Turkey was unab...
# 674  Abbas is the assistant of Sakir who is a rogue...
#
#                                              Directors  \
# 5    ['Joaquim Dos Santos', 'Kemp Powers', 'Justin ...
# 6    ['Christopher Nolan', 'Christian Bale', 'Heath...
# 7    ['Steven Spielberg', 'Liam Neeson', 'Ralph Fie...
# 8    ['Sidney Lumet', 'Henry Fonda', 'Lee J. Cobb',...
# 9    ['Francis Ford Coppola', 'Al Pacino', 'Robert ...
# ..                                                 ...
# 670  ['Çagan Irmak', 'Çetin Tekindor', 'Yigit Özsen...
# 671  ['Ketan Mehta', 'Nawazuddin Siddiqui', 'Abhina...
# 672  ['Puri Jagannadh', 'Mahesh Babu', "Ileana D'Cr...
# 673  ['Tolga Örnek', 'Haluk Bilginer', 'Taner Birse...
# 674  ['Sinan Çetin', 'Ilyas Salman', 'Sener Sen', '...
#
#                                                  Stars    Votes      Gross  \
# 5    ['Kemp Powers', 'Justin K. Thompson', 'Shameik...   122030     122030
# 6    ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...  2725188  534858444
# 7    ['Liam Neeson', 'Ralph Fiennes', 'Ben Kingsley...  1387831   96898818
# 8    ['Henry Fonda', 'Lee J. Cobb', 'Martin Balsam'...   815205    4360000
# 9    ['Al Pacino', 'Robert De Niro', 'Robert Duvall...  1303858   57300000
# ..                                                 ...      ...        ...
# 670  ['Çetin Tekindor', 'Yigit Özsener', 'Gökçe Bah...    11023      11023
# 671  ['Nawazuddin Siddiqui', 'Abhinay Raj Singh', '...    19577      19577
# 672  ['Mahesh Babu', "Ileana D'Cruz", 'Prakash Raj'...    15030      15030
# 673  ['Haluk Bilginer', 'Taner Birsel', 'Charles Ca...    12416      12416
# 674  ['Ilyas Salman', 'Sener Sen', 'Aysen Gruda', '...    10818      10818
#
#                                       Link
# 5    https://www.imdb.com/title/tt9362722/
# 6    https://www.imdb.com/title/tt0468569/
# 7    https://www.imdb.com/title/tt0108052/
# 8    https://www.imdb.com/title/tt0050083/
# 9    https://www.imdb.com/title/tt0071562/
# ..                                     ...
# 670  https://www.imdb.com/title/tt2150209/
# 671  https://www.imdb.com/title/tt3449292/
# 672  https://www.imdb.com/title/tt0816258/
# 673  https://www.imdb.com/title/tt1282139/
# 674  https://www.imdb.com/title/tt0263208/
#
# [670 rows x 12 columns]

# %% [markdown]
# The above can be rewritten more concisely using the `.between()` method:

# %%
movies_df[movies_df["Rating"].between(8, 9)]
# Out:
#       ID                                title  Rating  Runtime  \
# 5      6  Spider-Man: Across the Spider-Verse     9.0  140 min
# 6      7                      The Dark Knight     9.0  152 min
# 7      8                     Schindler's List     9.0  195 min
# 8      9                         12 Angry Men     9.0   96 min
# 9     10                The Godfather Part II     9.0  202 min
# ..   ...                                  ...     ...      ...
# 670  671              My Grandfather's People     8.0  126 min
# 671  672             Manjhi: The Mountain Man     8.0  120 min
# 672  673                               Pokiri     8.0  164 min
# 673  674               Cars of the Revolution     8.0  115 min
# 674  675                      Abbas in Flower     8.0   87 min
#
#                             Genre  Metascore  \
# 5    Animation, Action, Adventure  86.000000
# 6            Action, Crime, Drama  84.000000
# 7       Biography, Drama, History  95.000000
# 8                    Crime, Drama  97.000000
# 9                    Crime, Drama  90.000000
# ..                            ...        ...
# 670         Comedy, Drama, Family  58.749625
# 671              Biography, Drama  58.749625
# 672       Action, Crime, Thriller  58.749625
# 673                         Drama  58.749625
# 674        Comedy, Drama, Romance  58.749625
#
#                                                   Plot  \
# 5    Miles Morales catapults across the Multiverse,...
# 6    When the menace known as the Joker wreaks havo...
# 7    In German-occupied Poland during World War II,...
# 8    The jury in a New York City murder trial is fr...
# 9    The early life and career of Vito Corleone in ...
# ..                                                 ...
# 670  Grandpapa and his family were torn from their ...
# 671  Using only a hammer and a chisel, a man spends...
# 672  A money-minded criminal has to deal with two r...
# 673  In the years of military coup, Turkey was unab...
# 674  Abbas is the assistant of Sakir who is a rogue...
#
#                                              Directors  \
# 5    ['Joaquim Dos Santos', 'Kemp Powers', 'Justin ...
# 6    ['Christopher Nolan', 'Christian Bale', 'Heath...
# 7    ['Steven Spielberg', 'Liam Neeson', 'Ralph Fie...
# 8    ['Sidney Lumet', 'Henry Fonda', 'Lee J. Cobb',...
# 9    ['Francis Ford Coppola', 'Al Pacino', 'Robert ...
# ..                                                 ...
# 670  ['Çagan Irmak', 'Çetin Tekindor', 'Yigit Özsen...
# 671  ['Ketan Mehta', 'Nawazuddin Siddiqui', 'Abhina...
# 672  ['Puri Jagannadh', 'Mahesh Babu', "Ileana D'Cr...
# 673  ['Tolga Örnek', 'Haluk Bilginer', 'Taner Birse...
# 674  ['Sinan Çetin', 'Ilyas Salman', 'Sener Sen', '...
#
#                                                  Stars    Votes      Gross  \
# 5    ['Kemp Powers', 'Justin K. Thompson', 'Shameik...   122030     122030
# 6    ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...  2725188  534858444
# 7    ['Liam Neeson', 'Ralph Fiennes', 'Ben Kingsley...  1387831   96898818
# 8    ['Henry Fonda', 'Lee J. Cobb', 'Martin Balsam'...   815205    4360000
# 9    ['Al Pacino', 'Robert De Niro', 'Robert Duvall...  1303858   57300000
# ..                                                 ...      ...        ...
# 670  ['Çetin Tekindor', 'Yigit Özsener', 'Gökçe Bah...    11023      11023
# 671  ['Nawazuddin Siddiqui', 'Abhinay Raj Singh', '...    19577      19577
# 672  ['Mahesh Babu', "Ileana D'Cruz", 'Prakash Raj'...    15030      15030
# 673  ['Haluk Bilginer', 'Taner Birsel', 'Charles Ca...    12416      12416
# 674  ['Ilyas Salman', 'Sener Sen', 'Aysen Gruda', '...    10818      10818
#
#                                       Link
# 5    https://www.imdb.com/title/tt9362722/
# 6    https://www.imdb.com/title/tt0468569/
# 7    https://www.imdb.com/title/tt0108052/
# 8    https://www.imdb.com/title/tt0050083/
# 9    https://www.imdb.com/title/tt0071562/
# ..                                     ...
# 670  https://www.imdb.com/title/tt2150209/
# 671  https://www.imdb.com/title/tt3449292/
# 672  https://www.imdb.com/title/tt0816258/
# 673  https://www.imdb.com/title/tt1282139/
# 674  https://www.imdb.com/title/tt0263208/
#
# [670 rows x 12 columns]

# %% [markdown]
# ## Sorting Values

# %%
movies_df.sort_values(by = ["Rating"], ascending=True)
# Out:
#         ID                                title  Rating  Runtime  \
# 9998  9999                          The Pyramid     4.6   89 min
# 9993  9994                               Driven     4.6  116 min
# 9992  9993                               Psycho     4.6  105 min
# 9994  9995                            Yogi Bear     4.6   80 min
# 9997  9998                          Dark Crimes     4.6   92 min
# ...    ...                                  ...     ...      ...
# 4        5                                Daman     9.1  121 min
# 2        3  Ramayana: The Legend of Prince Rama     9.2  135 min
# 3        4                      The Chaos Class     9.2   87 min
# 1        2                        The Godfather     9.2  175 min
# 0        1             The Shawshank Redemption     9.3  142 min
#
#                              Genre   Metascore  \
# 9998     Horror, Mystery, Thriller   24.000000
# 9993          Action, Drama, Sport   29.000000
# 9992     Horror, Mystery, Thriller   47.000000
# 9994  Animation, Adventure, Comedy   35.000000
# 9997         Crime, Drama, Mystery   24.000000
# ...                            ...         ...
# 4                 Adventure, Drama   58.749625
# 2     Animation, Action, Adventure   58.749625
# 3                    Comedy, Drama   58.749625
# 1                     Crime, Drama  100.000000
# 0                            Drama   82.000000
#
#                                                    Plot  \
# 9998  An archaeological team attempts to unlock the ...
# 9993  A young hot shot driver is in the middle of a ...
# 9992  A young female embezzler arrives at the Bates ...
# 9994  A documentary filmmaker travels to Jellystone ...
# 9997  A murder investigation of a slain businessman ...
# ...                                                 ...
# 4     The film is set in 2015. Sid, is a young docto...
# 2     An anime adaptation of the Hindu epic the Rama...
# 3     Lazy, uneducated students share a very close b...
# 1     Don Vito Corleone, head of a mafia family, dec...
# 0     Over the course of several years, two convicts...
#
#                                               Directors  \
# 9998  ['Grégory Levasseur', 'Ashley Hinshaw', 'James...
# 9993  ['Renny Harlin', 'Sylvester Stallone', 'Kip Pa...
# 9992  ['Gus Van Sant', 'Vince Vaughn', 'Anne Heche',...
# 9994  ['Eric Brevig', 'Dan Aykroyd', 'Justin Timberl...
# 9997  ['Alexandros Avranas', 'Jim Carrey', 'Marton C...
# ...                                                 ...
# 4     ['Lenka Debiprasad', 'Vishal Mourya', 'Karan K...
# 2     ['Ram Mohan', 'Yûgô Sakô', 'Koichi Saski', 'Ar...
# 3     ['Ertem Egilmez', 'Kemal Sunal', 'Münir Özkul'...
# 1     ['Francis Ford Coppola', 'Marlon Brando', 'Al ...
# 0     ['Frank Darabont', 'Tim Robbins', 'Morgan Free...
#
#                                                   Stars    Votes      Gross  \
# 9998  ['Ashley Hinshaw', 'James Buckley', "Denis O'H...    25483    2756333
# 9993  ['Sylvester Stallone', 'Kip Pardue', 'Til Schw...    42226   32720065
# 9992  ['Vince Vaughn', 'Anne Heche', 'Julianne Moore...    49548   21456130
# 9994  ['Dan Aykroyd', 'Justin Timberlake', 'Anna Far...    22762  100246011
# 9997  ['Jim Carrey', 'Marton Csokas', 'Charlotte Gai...    19098      19098
# ...                                                 ...      ...        ...
# 4     ['Vishal Mourya', 'Karan Kandhapan', 'Babushan...    13303      13303
# 2     ['Yûgô Sakô', 'Koichi Saski', 'Arun Govil', 'N...    10108      10108
# 3     ['Kemal Sunal', 'Münir Özkul', 'Halit Akçatepe...    41785      41785
# 1     ['Marlon Brando', 'Al Pacino', 'James Caan', '...  1914751  134966411
# 0     ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...  2752419   28341469
#
#                                         Link
# 9998   https://www.imdb.com/title/tt2799166/
# 9993   https://www.imdb.com/title/tt0132245/
# 9992   https://www.imdb.com/title/tt0155975/
# 9994   https://www.imdb.com/title/tt1302067/
# 9997   https://www.imdb.com/title/tt1901024/
# ...                                      ...
# 4     https://www.imdb.com/title/tt17592606/
# 2      https://www.imdb.com/title/tt0259534/
# 3      https://www.imdb.com/title/tt0252487/
# 1      https://www.imdb.com/title/tt0068646/
# 0      https://www.imdb.com/title/tt0111161/
#
# [9999 rows x 12 columns]

# %%
movies_df.sort_values(by = ["Rating", "Votes"], ascending=[True, False])
# Out:
#         ID                                title  Rating  Runtime  \
# 9988  9989         Aliens vs. Predator: Requiem     4.6   94 min
# 9983  9984                  Fifty Shades Darker     4.6  118 min
# 9985  9986                           Death Note     4.6  101 min
# 9984  9985                      Superhero Movie     4.6   75 min
# 9996  9997                Paranormal Activity 4     4.6   88 min
# ...    ...                                  ...     ...      ...
# 4        5                                Daman     9.1  121 min
# 1        2                        The Godfather     9.2  175 min
# 3        4                      The Chaos Class     9.2   87 min
# 2        3  Ramayana: The Legend of Prince Rama     9.2  135 min
# 0        1             The Shawshank Redemption     9.3  142 min
#
#                              Genre   Metascore  \
# 9988     Action, Adventure, Horror   29.000000
# 9983      Drama, Romance, Thriller   33.000000
# 9985         Crime, Drama, Fantasy   43.000000
# 9984        Action, Comedy, Sci-Fi   33.000000
# 9996               Horror, Mystery   40.000000
# ...                            ...         ...
# 4                 Adventure, Drama   58.749625
# 1                     Crime, Drama  100.000000
# 3                    Comedy, Drama   58.749625
# 2     Animation, Action, Adventure   58.749625
# 0                            Drama   82.000000
#
#                                                    Plot  \
# 9988  Warring Alien and Predator races descend on a ...
# 9983  While Christian wrestles with his inner demons...
# 9985  A high school student named Light Turner disco...
# 9984  Orphaned high school student Rick Riker is bit...
# 9996  It has been five years since the disappearance...
# ...                                                 ...
# 4     The film is set in 2015. Sid, is a young docto...
# 1     Don Vito Corleone, head of a mafia family, dec...
# 3     Lazy, uneducated students share a very close b...
# 2     An anime adaptation of the Hindu epic the Rama...
# 0     Over the course of several years, two convicts...
#
#                                               Directors  \
# 9988  ['Colin Strause', 'Greg Strause', 'Reiko Ayles...
# 9983  ['James Foley', 'Dakota Johnson', 'Jamie Dorna...
# 9985  ['Adam Wingard', 'Nat Wolff', 'LaKeith Stanfie...
# 9984  ['Craig Mazin', 'Drake Bell', 'Leslie Nielsen'...
# 9996  ['Henry Joost', 'Ariel Schulman', 'Stephen Dun...
# ...                                                 ...
# 4     ['Lenka Debiprasad', 'Vishal Mourya', 'Karan K...
# 1     ['Francis Ford Coppola', 'Marlon Brando', 'Al ...
# 3     ['Ertem Egilmez', 'Kemal Sunal', 'Münir Özkul'...
# 2     ['Ram Mohan', 'Yûgô Sakô', 'Koichi Saski', 'Ar...
# 0     ['Frank Darabont', 'Tim Robbins', 'Morgan Free...
#
#                                                   Stars    Votes      Gross  \
# 9988  ['Greg Strause', 'Reiko Aylesworth', 'Steven P...   129456   41797066
# 9983  ['Dakota Johnson', 'Jamie Dornan', 'Eric Johns...   106578  114376885
# 9985  ['Nat Wolff', 'LaKeith Stanfield', 'Margaret Q...    87627      87627
# 9984  ['Drake Bell', 'Leslie Nielsen', 'Sara Paxton'...    72271   26638520
# 9996  ['Ariel Schulman', 'Stephen Dunham', 'Katie Fe...    68430   53921300
# ...                                                 ...      ...        ...
# 4     ['Vishal Mourya', 'Karan Kandhapan', 'Babushan...    13303      13303
# 1     ['Marlon Brando', 'Al Pacino', 'James Caan', '...  1914751  134966411
# 3     ['Kemal Sunal', 'Münir Özkul', 'Halit Akçatepe...    41785      41785
# 2     ['Yûgô Sakô', 'Koichi Saski', 'Arun Govil', 'N...    10108      10108
# 0     ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...  2752419   28341469
#
#                                         Link
# 9988   https://www.imdb.com/title/tt0758730/
# 9983   https://www.imdb.com/title/tt4465564/
# 9985   https://www.imdb.com/title/tt1241317/
# 9984   https://www.imdb.com/title/tt0426592/
# 9996   https://www.imdb.com/title/tt2109184/
# ...                                      ...
# 4     https://www.imdb.com/title/tt17592606/
# 1      https://www.imdb.com/title/tt0068646/
# 3      https://www.imdb.com/title/tt0252487/
# 2      https://www.imdb.com/title/tt0259534/
# 0      https://www.imdb.com/title/tt0111161/
#
# [9999 rows x 12 columns]

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### The `.describe()` Method
#
# Using `describe()` on an entire `DataFrame` we can get a summary of the distribution of *continuous* variables

# %%
movies_df.describe()
# Out:
#                 ID       Rating    Metascore         Votes         Gross
# count  9999.000000  9999.000000  9999.000000  9.999000e+03  9.999000e+03
# mean   5000.000000     6.698620    58.749625  9.127103e+04  2.874067e+07
# std    2886.607005     0.852755    15.620576  1.684508e+05  5.971933e+07
# min       1.000000     4.600000     7.000000  1.000100e+04  7.000000e+00
# 25%    2500.500000     6.100000    49.000000  1.678500e+04  3.654100e+04
# 50%    5000.000000     6.700000    58.749625  3.391200e+04  4.244155e+06
# 75%    7499.500000     7.300000    68.000000  8.965600e+04  3.306295e+07
# max    9999.000000     9.300000   100.000000  2.752419e+06  9.366622e+08

# %% [markdown]
# It shows the non-null count, mean, standard deviation, min and max values, and the values of the quartiles of each continuous variable.
#
# In the above, the summary of the `ID` column is irrelevant since it does not represent actual data.

# %% [markdown]
# The `Runtime` column contains the length of each movie in minutes, this should logically make the column `integer` type, however, each value is suffixed with the word `"min"`, therefore, the column is `string` type. We need to split the values of this column, take the first item after splitting and convert that to integer type.

# %%
movies_df['Runtime'] = movies_df['Runtime'].str.split().str[0].astype(int)

# %%
movies_df.drop('ID', axis = 1).describe()    # summary without the ID column
# Out:
#             Rating      Runtime    Metascore         Votes         Gross
# count  9999.000000  9999.000000  9999.000000  9.999000e+03  9.999000e+03
# mean      6.698620   110.479148    58.749625  9.127103e+04  2.874067e+07
# std       0.852755    21.995584    15.620576  1.684508e+05  5.971933e+07
# min       4.600000    45.000000     7.000000  1.000100e+04  7.000000e+00
# 25%       6.100000    96.000000    49.000000  1.678500e+04  3.654100e+04
# 50%       6.700000   106.000000    58.749625  3.391200e+04  4.244155e+06
# 75%       7.300000   120.000000    68.000000  8.965600e+04  3.306295e+07
# max       9.300000   439.000000   100.000000  2.752419e+06  9.366622e+08

# %% [markdown]
# The `.describe()` method can also be run on individual non-numeric columns:

# %%
movies_df['Genre'].describe()
# Out:
# count                       9999
# unique                       428
# top       Comedy, Drama, Romance
# freq                         480
# Name: Genre, dtype: object

# %% [markdown]
# It shows the count of the non-null values, the number of unique values, the value that appears the most and how many times it appears (`freq`).

# %% [markdown]
# ### The `.value_counts()` method
# For a categorical column, we can also run `.value_counts()`:

# %%
movies_df.Genre.value_counts()
# here, movies_df.Genre is the same as movies_df.['Genre']
# Out:
# Genre
# Comedy, Drama, Romance       480
# Drama                        433
# Comedy, Drama                408
# Drama, Romance               336
# Action, Crime, Drama         325
#                             ...
# Action, Thriller, Western      1
# Action, Drama, Music           1
# Comedy, Fantasy, Thriller      1
# Adventure, Crime               1
# Family, Sci-Fi                 1
# Name: count, Length: 428, dtype: int64

# %% [markdown]
# ### The `.corr()` Method
# Returns a correlation matrix

# %%
movies_df.drop('ID', axis = 1).corr(numeric_only=True)
# Out:
#              Rating   Runtime  Metascore     Votes     Gross
# Rating     1.000000  0.345162   0.623556  0.307727  0.064945
# Runtime    0.345162  1.000000   0.181856  0.197374  0.124496
# Metascore  0.623556  0.181856   1.000000  0.202101  0.029370
# Votes      0.307727  0.197374   0.202101  1.000000  0.632156
# Gross      0.064945  0.124496   0.029370  0.632156  1.000000

# %% [markdown]
# ## Computing New Columns

# %%
# creating a column depticcting gross revenue per minute of runtime
mv_idx['revenue_per_minute'] = movies_df['Gross'] / movies_df['Runtime']
mv_idx['revenue_per_minute'].head()
# Out:
# ID
# 1    771236.634286
# 2        74.874074
# 3       480.287356
# 4       109.942149
# 5       871.642857
# Name: revenue_per_minute, dtype: float64

# %% [markdown]
# ### The `.transform()` Method
#
# This method applies a function to an axis (either column or row) and returns a `DataFrame` of the same shape.
#
# We can mention `axis=1` for applying the function across the columns (row-wise), meaning that with `axis=1`, the function will get individual rows as input. Otherwise, it is column-wise.
#
# For example, if we wanted to standardize the rating column:

# %%
mv_idx['rating_standardized'] = mv_idx['Rating'].transform(lambda x: (x-x.mean())/x.std())

# %%
mv_idx['rating_standardized'].head()
# Out:
# ID
# 1    3.050559
# 2    2.933292
# 3    2.933292
# 4    2.933292
# 5    2.816025
# Name: rating_standardized, dtype: float64

# %%
mv_idx['rating_standardized'].mean()
# Out:
# np.float64(-1.3643784905084433e-16)

# %%
mv_idx['rating_standardized'].std()
# Out:
# 1.0000000000000062

# %% [markdown]
# ### The `.assign()` method
#
# Assigns new columns to a `DataFrame`. Returns a new object with all original columns in addition to new ones. Existing columns that are re-assigned will be overwritten.

# %%
mv_idx = mv_idx.assign(
    rating_out_of_1 = mv_idx['Rating'] / 10,
    revenue_std = lambda df: (df['Gross'] - df['Gross'].mean())/df['Gross'].std()
)

mv_idx[['rating_out_of_1', 'revenue_std']].head()
# Out:
#     rating_out_of_1  revenue_std
# ID
# 1              0.93    -0.006685
# 2              0.92     1.778750
# 3              0.92    -0.481093
# 4              0.92    -0.480563
# 5              0.91    -0.481040

# %% [markdown]
# ### Discretization and Binning
#
# Sometimes we need to numeric/continuous columns to categorical/discrete columns.

# %% [markdown]
# #### Using `pd.cut()`
#
# This functions "cuts" continuous variable into several groups making it discrete or categorical.
#
# ```
# pandas.cut(x, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False, duplicates='raise', ordered=True)
# ```
#
# Parameters:
# - x: array-like (series/column). The input array to be binned. Must be 1-dimensional.
#
# - bins: int, sequence of scalars, or IntervalIndex. The criteria to bin by.
#     - int : Defines the number of equal-width bins in the range of x. The range of x is extended by .1% on each side to include the minimum and maximum values of x.
#     - sequence of scalars : Defines the bin edges allowing for non-uniform width. No extension of the range of x is done.
#     - IntervalIndex : Defines the exact bins to be used. Note that IntervalIndex for bins must be non-overlapping.
# - right: bool, default=True. Indicates whether bins includes the rightmost edge or not. If right == True (the default), then the bins [1, 2, 3, 4] indicate (1,2], (2,3], (3,4]. This argument is ignored when bins is an IntervalIndex.
# - labels: array or False, default=None. Specifies the labels for the returned bins. Must be the same length as the resulting bins.
# - include_lowest: bool, default=False. Whether the first interval should be left-inclusive or not.
# - ordered: bool, default=True. Whether the labels are ordered or not. Applies to returned types Categorical and Series (with Categorical dtype). If True, the resulting categorical will be ordered. If False, the resulting categorical will be unordered (labels must be provided).

# %%
rating_cat = pd.cut(movies_df['Rating'], 3)
rating_cat.value_counts()
# Out:
# Rating
# (6.167, 7.733]    6255
# (4.595, 6.167]    2650
# (7.733, 9.3]      1094
# Name: count, dtype: int64

# %% [markdown]
# Can mention `right = False` to include lower limits and not upper limits:

# %%
rating_cat2 = pd.cut(movies_df['Rating'], 3, right = False)
rating_cat2.value_counts()
# Out:
# Rating
# [6.167, 7.733)    6255
# [4.6, 6.167)      2650
# [7.733, 9.305)    1094
# Name: count, dtype: int64

# %%
rating_cat3 = pd.cut(movies_df['Rating'], 3, include_lowest=True)
rating_cat3.value_counts()
# Out:
# Rating
# (6.167, 7.733]                6255
# (4.593999999999999, 6.167]    2650
# (7.733, 9.3]                  1094
# Name: count, dtype: int64

# %%
rating_cat4 = pd.cut(movies_df.Rating, [0, 5, 8, 10], right = True)
rating_cat4.value_counts()
# Out:
# Rating
# (5, 8]     9204
# (8, 10]     496
# (0, 5]      299
# Name: count, dtype: int64

# %% [markdown]
# Can also provide a `list` of labels for each category using the `labels` argument:

# %%
rating_cat5 = pd.cut(movies_df.Rating, [0, 5, 8, 10], labels = ['<=5', '5-8', '>8'])
rating_cat5.value_counts()
# Out:
# Rating
# 5-8    9204
# >8      496
# <=5     299
# Name: count, dtype: int64

# %% [markdown]
# #### `pd.qcut()`
#
# Quantile-based discretization function. Uses sample quantiles to bin.
#
# ```
# Parameters
# ----------
# x : 1d ndarray or Series
# q : int or list-like of float
#     int: Number of quantiles. 10 for deciles, 4 for quartiles, etc.
#     list: Alternately array of quantiles, e.g. [0, .25, .5, .75, 1.] for quartiles.
# labels : array or False, default None
#     Used as labels for the resulting bins. Must be of the same length as
#     the resulting bins. If False, return only integer indicators of the
#     bins. If True, raises an error.
# retbins : bool, optional
#     Whether to return the (bins, labels) or not. Can be useful if bins
#     is given as a scalar.
# ```

# %%
pd.qcut(x = movies_df.Rating, q = 3).value_counts()
# Out:
# Rating
# (4.598999999999999, 6.3]    3441
# (6.3, 7.1]                  3309
# (7.1, 9.3]                  3249
# Name: count, dtype: int64

# %%
pd.qcut(x = movies_df.Rating, q = [0, 0.25, 0.5, 0.75, 1]).value_counts()
# Out:
# Rating
# (4.598999999999999, 6.1]    2650
# (6.1, 6.7]                  2476
# (6.7, 7.3]                  2468
# (7.3, 9.3]                  2405
# Name: count, dtype: int64

# %% [markdown]
# ### Aggregation
#
# Aggregation functions are used to obtain summary information on columns of a dataframe using the `.agg()` method

# %% [markdown]
# #### Method 1: providing a callable function function to `.agg()`

# %%
import numpy as np

# %%
movies_df[["Gross", "Rating"]].agg(np.mean)
# Out:
# /tmp/ipython-input-2274451635.py:1: FutureWarning: The provided callable <function mean at 0x79daba578220> is currently using DataFrame.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   movies_df[["Gross", "Rating"]].agg(np.mean)
# Gross     2.874067e+07
# Rating    6.698620e+00
# dtype: float64

# %% [markdown]
# Can also pass a lambda function:

# %%
movies_df[["Rating", "Gross"]].agg(lambda x: np.mean(x))
# Out:
# Rating    6.698620e+00
# Gross     2.874067e+07
# dtype: float64

# %% [markdown]
# #### Method 2: Selecting the columns, then providing the aggregation function name as strings to `.agg()` as a list of string:

# %%
movies_df[["Gross", "Rating"]].agg(["max", "min", "mean"])
# Out:
#              Gross   Rating
# max   9.366622e+08  9.30000
# min   7.000000e+00  4.60000
# mean  2.874067e+07  6.69862

# %% [markdown]
# #### Method 3: Passing tuples of column name and aggregate function name as string

# %%
movies_df.agg(max_revenue = ("Gross", "max"), min_revenue = ("Gross", "min"), max_rating = ("Rating", "max"))
# Out:
#                    Gross  Rating
# max_revenue  936662225.0     NaN
# min_revenue          7.0     NaN
# max_rating           NaN     9.3

# %% [markdown]
# #### Method 4: Passing a dictionary with keys as column names on which to perform the aggregation, and lists of aggregating function names as strings as the values to the corresponding keys of the dictionary

# %%
movies_df.agg({
    "Rating" : ["mean", "min", "max"],
    "Gross" : ["min", "max", "std"]
})
# Out:
#        Rating         Gross
# mean  6.69862           NaN
# min   4.60000  7.000000e+00
# max   9.30000  9.366622e+08
# std       NaN  5.971933e+07

# %% [markdown]
# Below is a non-comprehensive list of `pandas` aggregation functions:
#
# | Function      | Description |
# |---------------|-------------|
# | sum           | Adds up the values. |
# | mean          | Computes the average of the values. |
# | median        | Returns the median value. |
# | min           | Gives the smallest value. |
# | max           | Gives the largest value. |
# | count         | Counts non-missing values. |
# | size          | Counts all rows, including missing values. |
# | nunique       | Counts distinct values. |
# | std           | Computes standard deviation. |
# | var           | Computes variance. |
# | prod          | Multiplies all values. |
# | first         | Returns the first non-missing value. |
# | last          | Returns the last non-missing value. |
# | idxmin        | Returns the index of the minimum value. |
# | idxmax        | Returns the index of the maximum value. |
# | quantile      | Returns a specified quantile. |
# | mad           | Computes mean absolute deviation. |
# | sem           | Computes standard error of the mean. |
# | skew          | Measures distribution skewness. |
# | kurt          | Measures distribution kurtosis. |
# | corr          | Computes correlation with another series. |
# | cov           | Computes covariance with another series. |
# | mode          | Returns the mode(s) of the values. |
# | any           | Tests if any element is True. |
# | all           | Tests if all elements are True. |
#
# Apart from the above, some `numpy` universal functions (`unfuncs`) can also be used.

# %% [markdown]
# ### Applying Functions and Mapping
#
#
# A frequent operation while analyzing a data is to apply a function on one-dimensional arrays to each column or each row. It can be done with the `.apply()` method of a `DataFrame`.
#
# The `.apply()` method takes a function as its argument as well as the axis *across* which the function is applied. The function can be built-in, from a package or a lambda.
#
# For example, we can define a function that returns the range and the 90th percentile of a variable:

# %%
def mysummary(x):
    return [x.max() - x.min(), x.quantile(0.90)]

# %% [markdown]
# If we want to find the range and the median of say, rating and gross revenue:

# %%
movies_df[['Rating', 'Gross']].apply(mysummary, axis=0)
# Out:
#    Rating        Gross
# 0     4.7  936662218.0
# 1     7.8   80572126.0

# %% [markdown]
# We can see that the two summary statistics returned from our defined function, namely, range and 90th percentile are indexed as 0 and 1, respectively in the output.
#
# While outputting multiple summary statistics, it is desirable to index those statistics with appropriate labels.
#
# We can provide appropriate labels to our outputs by returning a Series instead of a list as follows:

# %%
def mysummary(x):
    return pd.Series([x.max() - x.min(), x.quantile(0.90)],
                    index = ['range', '90th Percentile'])
movies_df[['Runtime', 'Gross']].apply(mysummary, axis=0)
# Out:
#                  Runtime        Gross
# range              394.0  936662218.0
# 90th Percentile    138.0   80572126.0

# %% [markdown]
# We can also invoke lambda functions inside the `.apply()` method instead of defining a function using the `def` keyword:

# %%
movies_df[['Runtime', 'Gross']].apply(
    lambda x: pd.Series(
        [x.max() - x.min(), x.quantile(0.90)],
        index = ['range', '90th Percentile']
    )
)
# Out:
#                  Runtime        Gross
# range              394.0  936662218.0
# 90th Percentile    138.0   80572126.0

# %% [markdown]
# Using apply() will be much faster than iterating manually over rows because pandas is utilizing vectorization.

# %% [markdown]
# ### Grouped aggregation
#
# When exploring and analyzing data, we often need to perform grouped analysis. For example, we may want to find the mean rating across the various genre of movies in the dataset.
#
# Since many of the movies belong to muultiple genre, there are too many combination of genres. So, we create a new column which keeps only the first genre of each movie:

# %%
movies_df['genre_one'] = movies_df['Genre'].str.split(',').str[0]

# %%
movies_df.groupby('genre_one')['Rating'].agg(('mean', 'std'))
# Out:
#                mean       std
# genre_one
# Action     6.508662  0.847091
# Adventure  6.697059  0.888265
# Animation  6.939545  0.822725
# Biography  7.103270  0.615411
# Comedy     6.579301  0.811387
# Crime      6.960520  0.792992
# Drama      6.963355  0.815379
# Family     6.575000  0.865544
# Fantasy    6.073333  0.851891
# Film-Noir  7.450000  0.374166
# History    6.200000       NaN
# Horror     6.057084  0.761298
# Music      7.100000       NaN
# Musical    7.250000  0.070711
# Mystery    6.707317  1.029901
# Romance    7.016667  0.479236
# Sci-Fi     6.455556  0.745170
# Thriller   6.186364  0.749155
# War        6.700000       NaN
# Western    7.457143  0.680336

# %%
# we can also obtain the mean of all numeric columns:
(
    movies_df
    .drop('ID', axis = 'columns')
    .groupby('genre_one')
    .mean(numeric_only=True)
)
# Out:
#              Rating     Runtime  Metascore          Votes         Gross
# genre_one
# Action     6.508662  116.259873  54.127302  133757.068790  4.655420e+07
# Adventure  6.697059  111.858456  58.425024  105576.055147  3.993996e+07
# Animation  6.939545   93.053830  63.501485  119680.146998  6.856429e+07
# Biography  7.103270  122.320138  64.098065   89606.306368  2.091005e+07
# Comedy     6.579301  104.664965  57.012691   61693.785546  2.284620e+07
# Crime      6.960520  112.345297  62.282406   92423.574257  1.343133e+07
# Drama      6.963355  114.678308  63.925404   73330.230694  1.452171e+07
# Family     6.575000  106.000000  56.937406   67858.500000  5.568126e+06
# Fantasy    6.073333   98.616667  52.454073   66293.233333  2.183054e+07
# Film-Noir  7.450000   98.625000  76.062406   49921.375000  1.510287e+06
# History    6.200000  102.000000  58.749625   11769.000000  1.176900e+04
# Horror     6.057084   95.983573  52.625698   73454.295688  1.968973e+07
# Music      7.100000   93.000000  61.000000   17916.000000  3.419967e+06
# Musical    7.250000  102.000000  66.374812   10498.500000  4.522161e+06
# Mystery    6.707317  111.439024  57.786485  154141.243902  1.843599e+07
# Romance    7.016667  111.166667  63.124937   66411.500000  1.838634e+07
# Sci-Fi     6.455556  102.777778  53.861069  114809.555556  1.349010e+07
# Thriller   6.186364  100.909091  54.420403   34096.500000  7.687018e+06
# War        6.700000  114.000000  55.000000   13078.000000  9.265000e+06
# Western    7.457143  123.428571  69.107089   71993.000000  1.386282e+07

# %% [markdown]
# ### More `.groupby` examples

# %%
ipl_data = {
    'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
    'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
    'Rank': [1, 2, 2, 3, 3, 4, 1, 1, 2, 4,1,2],
    'Year': [2014, 2015, 2014, 2015, 2014, 2015, 2016, 2017, 2016, 2014, 2015, 2017],
    'Points':[876, 789, 863, 673, 741, 812, 756, 788, 694, 701, 804, 690]
}
df2 = pd.DataFrame(ipl_data)
df2
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df2.groupby('Team')    # returns a DataFrameGroupBy object

# %%
# returns a dictionary containing group names as keys and list of indices of each group member
df2.groupby('Team').groups
# Out:
# {'Devils': [2, 3], 'Kings': [4, 6, 7], 'Riders': [0, 1, 8, 11], 'Royals': [9, 10], 'kings': [5]}

# %%
# can also group by multiple columns
df2.groupby(['Team', 'Year']).groups
# Out:
# {('Devils', 2014): [2], ('Devils', 2015): [3], ('Kings', 2014): [4], ('Kings', 2016): [6], ('Kings', 2017): [7], ('Riders', 2014): [0], ('Riders', 2015): [1], ('Riders', 2016): [8], ('Riders', 2017): [11], ('Royals', 2014): [9], ('Royals', 2015): [10], ('kings', 2015): [5]}

# %%
# we can iterate over groups using a loop
grouped = df2.groupby('Year')

for name, group in grouped:
   print(name)
   print(group)
# Out:
# 2014
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701
# 2015
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 10  Royals     1  2015     804
# 2016
#      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694
# 2017
#       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %%
# we can extract the data of a single group
grouped.get_group(2014)    # a dataframe with Year 2014 only
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701

# %%
grouped2 = df2.groupby('Team')
grouped2['Points'].agg('mean')
# Out:
# Team
# Devils    768.000000
# Kings     761.666667
# Riders    762.250000
# Royals    752.500000
# kings     812.000000
# Name: Points, dtype: float64

# %%
grouped2['Points'].agg(['sum', 'mean', 'std'])
# Out:
#          sum        mean         std
# Team
# Devils  1536  768.000000  134.350288
# Kings   2285  761.666667   24.006943
# Riders  3049  762.250000   88.567771
# Royals  1505  752.500000   72.831998
# kings    812  812.000000         NaN

# %%
# grouped transformation:
## standardizing the vaiables
grouped2['Points'].transform(lambda x: (x - x.mean()) / x.std()*10)
# Out:
# 0     12.843272
# 1      3.020286
# 2      7.071068
# 3     -7.071068
# 4     -8.608621
# 5           NaN
# 6     -2.360428
# 7     10.969049
# 8     -7.705963
# 9     -7.071068
# 10     7.071068
# 11    -8.157595
# Name: Points, dtype: float64

# %%
# filtering in a grouped context
## keeping teams which appears at least three times in the data
grouped2.filter(lambda x: len(x) >= 3)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 4    Kings     3  2014     741
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690

# %% [markdown]
# #### Groupby the summarize/aggregate

# %%
data = {
    "state" : ["Ohio"]*3 + ["Nevada"]*3,
    "year" : [2000, 2001, 2002, 2001, 2002, 2003],
    "popn" : [1.5, 1.7, 3.6, 2.4, 2.9, 3.2],
    "wt" : [1, 2, 3] * 2    # weights for findingg weighted average
}
df = pd.DataFrame(data)
df
# Out:
#     state  year  popn  wt
# 0    Ohio  2000   1.5   1
# 1    Ohio  2001   1.7   2
# 2    Ohio  2002   3.6   3
# 3  Nevada  2001   2.4   1
# 4  Nevada  2002   2.9   2
# 5  Nevada  2003   3.2   3

# %%
df.groupby("state").agg(avg_pop = ("popn", "mean"))    # returns a dataframe
# Out:
#          avg_pop
# state
# Nevada  2.833333
# Ohio    2.266667

# %%
# finding weighted average
df.groupby("state").apply(lambda g: sum(g.popn * g.wt) / sum(g.wt))    # returns a Series
# Out:
# /tmp/ipython-input-2457851632.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("state").apply(lambda g: sum(g.popn * g.wt) / sum(g.wt))    # returns a Series
# state
# Nevada    2.966667
# Ohio      2.616667
# dtype: float64

# %%
# wrapping the result in a Series makes the whole thing a dataframe
df.groupby("state").apply(
    lambda g: pd.Series(
        {"wt_avg" : sum(g.popn * g.wt) / sum(g.wt)}
    )
)
# Out:
# /tmp/ipython-input-1900871211.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("state").apply(
#           wt_avg
# state
# Nevada  2.966667
# Ohio    2.616667

# %%
# this returns a dataframe
agdf = (
    df.groupby(df.state).apply(
        lambda x: pd.Series(
            {
                "avg" : np.mean(x.popn),
                "wt_avg" : sum(x.popn * x.wt)/sum(x.wt),
                "wt_sum" : sum(x.popn * x.wt)
            }
            )
        )
    )

agdf
# Out:
# /tmp/ipython-input-3331310557.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby(df.state).apply(
#              avg    wt_avg  wt_sum
# state
# Nevada  2.833333  2.966667    17.8
# Ohio    2.266667  2.616667    15.7

# %% [markdown]
# #### Groupby then mutate

# %%
df.join(agdf, on = "state")
# Out:
#     state  year  popn  wt       avg    wt_avg  wt_sum
# 0    Ohio  2000   1.5   1  2.266667  2.616667    15.7
# 1    Ohio  2001   1.7   2  2.266667  2.616667    15.7
# 2    Ohio  2002   3.6   3  2.266667  2.616667    15.7
# 3  Nevada  2001   2.4   1  2.833333  2.966667    17.8
# 4  Nevada  2002   2.9   2  2.833333  2.966667    17.8
# 5  Nevada  2003   3.2   3  2.833333  2.966667    17.8

# %%
df["avg_pop2"] = df.groupby(df.state)["popn"].transform(lambda x: x.mean())
df
# Out:
#     state  year  popn  wt  avg_pop2
# 0    Ohio  2000   1.5   1  2.266667
# 1    Ohio  2001   1.7   2  2.266667
# 2    Ohio  2002   3.6   3  2.266667
# 3  Nevada  2001   2.4   1  2.833333
# 4  Nevada  2002   2.9   2  2.833333
# 5  Nevada  2003   3.2   3  2.833333

# %%
(
    df
    .groupby("state", group_keys = False)
    .apply(
        lambda grp: grp.assign(
            wt_avg2 = lambda x: sum(x.popn * x.wt) / sum(x.wt)
        ),
    )
)
# Out:
# /tmp/ipython-input-268474034.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#     state  year  popn  wt  avg_pop2   wt_avg2
# 0    Ohio  2000   1.5   1  2.266667  2.616667
# 1    Ohio  2001   1.7   2  2.266667  2.616667
# 2    Ohio  2002   3.6   3  2.266667  2.616667
# 3  Nevada  2001   2.4   1  2.833333  2.966667
# 4  Nevada  2002   2.9   2  2.833333  2.966667
# 5  Nevada  2003   3.2   3  2.833333  2.966667
